# %%
from data_common.notebook import *

# catalog.py incorporates this into the main flow

# %%
import os
import openai
import json
from tqdm import tqdm

openai.api_key = os.getenv("OPENAI_API_KEY")


class ResultsCache:
    filename = Path("data", "interim", "openai_cache.json")

    def __init__(self):
        if self.filename.exists():
            with open(self.filename, "r") as f:
                self.cache = json.load(f)
        else:
            self.cache = {}

    def __getitem__(self, key: str):
        return self.cache[key]

    def __setitem__(self, key: str, value: dict):
        self.cache[key] = value
        self.save()

    def save(self):
        with open(self.filename, "w") as f:
            json.dump(self.cache, f, indent=4)

    def stash_pairs(self, petitions: list[str], results: list[dict]):
        for petition, result in zip(petitions, results):
            self[petition] = result


def is_environmental_only_ten(
    list_of_petitions: list[str], recursion: int = 0
) -> list[dict[str, str]]:
    """
    Given a list of strings, will query the OpenAI API to determine if the petition is enviromental in nature.
    Only allows lists of length 1-10.
    """

    if len(list_of_petitions) > 10:
        raise ValueError("List of petitions must be less than 10 items")

    base_prompt = """Evaulate based on the names of a list of petitions made to the UK Parliament if they are enviromental in nature
    Environmental petitions are those related to climate change, net zero, carbon emissions, air pollution, water pollution, wildlife, ecology, forests, hunting, active travel, cycling, footpaths, etc.
    The original list is a Json encoded list of strings.
    Return a json list as the input list with the structure ["result": bool, "explanation": str, "stub": str (first ten characters of petition)].
    JSON bools are true and false, not True and False.
    The input and the output must have the same length.

    Petition names:
    """

    prompt = base_prompt + json.dumps(list_of_petitions) + "\n\nOutput:\n"

    response = openai.Completion.create(
        model="text-davinci-003",
        prompt=prompt,
        temperature=0.7,
        max_tokens=256 * 4,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
    )

    try:
        data = json.loads(response.choices[0].text)  # type: ignore
    except json.JSONDecodeError:
        print(response.choices[0].text)  # type: ignore
        raise ValueError("OpenAI API returned invalid JSON")

    # if the output list is not the same length as the input list, try again
    if len(data) != len(list_of_petitions):
        if recursion > 5:
            print(data)
            raise ValueError("OpenAI API is not returning the full list of results")
        return is_environmental_only_ten(list_of_petitions, recursion=recursion + 1)

    return data


def is_environmental(
    list_of_petitions: list[str], ignore_cache: bool = False
) -> list[dict[str, str]]:
    """
    Given a list of strings, will query the OpenAI API to determine if the petition is enviromental in nature.
    """

    cache = ResultsCache()
    if ignore_cache:
        not_in_cache = list_of_petitions
    else:
        not_in_cache = [
            petition for petition in list_of_petitions if petition not in cache.cache
        ]

    if not_in_cache:
        # send 10 at a time
        results = []
        for i in tqdm(range(0, len(not_in_cache), 10)):
            results.extend(is_environmental_only_ten(not_in_cache[i : i + 10]))
        cache.stash_pairs(not_in_cache, results)

    return [cache[petition] for petition in list_of_petitions]

# %%
df = pd.read_csv(Path("data", "interim", "petitions.csv"))

# highest signature_count to top
df = df.sort_values(by="signature_count", ascending=False)

# limit to petitions with more than 1000 signatures
df = df[df["signature_count"] > 1000]

# constructed joined action and background columns
full_text = df["action"] + " " + df["background"]

# run environment check on full_text
results = is_environmental(full_text.tolist())

df["is_environmental"] = [result["result"] for result in results]
df["openai_explanation"] = [result["explanation"] for result in results]

df
# Out:
# 100%|██████████| 1/1 [00:02<00:00,  2.94s/it]
#           id                                                url   state  \
# 1228  619781  https://petition.parliament.uk/petitions/61978...    open
# 423   590282  https://petition.parliament.uk/petitions/59028...  closed
# 3479  319891  https://petition.parliament.uk/petitions/31989...  closed
# 2516  326066  https://petition.parliament.uk/petitions/32606...  closed
# 424   619334  https://petition.parliament.uk/petitions/61933...    open
# ...      ...                                                ...     ...
# 3489  588774  https://petition.parliament.uk/petitions/58877...  closed
# 32    549072  https://petition.parliament.uk/petitions/54907...  closed
# 1117  600138  https://petition.parliament.uk/petitions/60013...  closed
# 3490  563118  https://petition.parliament.uk/petitions/56311...  closed
# 2558  601415  https://petition.parliament.uk/petitions/60141...  closed
#
#                                                  action  \
# 1228  Call an immediate general election to end the ...
# 423   Give the UK a Bank Holiday on Monday July 12th...
# 3479  Limit the Sale and Use of Fireworks to Organis...
# 2516                  Cancel GCSEs and A Levels in 2021
# 424       Include abortion rights in the Bill of Rights
# ...                                                 ...
# 3489  Exempt vehicles that use sustainable fuels fro...
# 32    UK Government to build UK Aid/Disaster Relief ...
# 1117  Require Water Companies to Refund Customers Wh...
# 3490  Exempt CO2 neutral Efuel & other cleaner fuel ...
# 2558  Prohibit the sale and use in the UK of palm oi...
#
#                                              background  \
# 1228  Call an immediate general election so that the...
# 423   England may be playing a European Championship...
# 3479  Current legislation allows for public use of f...
# 2516  The Government should cancel GCSEs and A Level...
# 424   As Parliament considers the Bill of Rights, th...
# ...                                                 ...
# 3489  The Government should exempt new car/van/motor...
# 32    To regenerate the UK shipbuilding Industry by ...
# 1117  It’s a consumer rights and pollution issue. We...
# 3490  Government should allow the sale & future deve...
# 2558  We call on the Government, now a study has est...
#
#                                      additional_details  signature_count  \
# 1228  The chaos engulfing the UK government is unpre...           901912
# 423   Sunday 8pm is a difficult time for families to...           364821
# 3479  Restrictions on the sale & use of fireworks ha...           301611
# 2516  Students in the UK have already missed hundred...           211974
# 424   In the wake of the United States Supreme Court...           167481
# ...                                                 ...              ...
# 3489  Sustainable fuels could use existing pumps/inf...             1027
# 32    The UK has no means of directly addressing dis...             1027
# 1117  Water companies have dumped sewage into rivers...             1021
# 3490  Alternative fuels use current infrastructure, ...             1019
# 2558  Palm oil is used in an extremely wide range of...             1005
#
#                   date_created date_responded date_debated  is_environmental  \
# 1228  2022-07-07T10:13:40.162Z     2022-09-20   2022-10-17             False
# 423   2021-06-30T09:01:23.069Z     2021-07-22          NaN             False
# 3479  2020-05-08T13:59:43.344Z     2020-08-13   2021-11-08              True
# 2516  2020-06-09T21:32:29.897Z     2020-10-20   2020-12-07             False
# 424   2022-06-29T19:18:39.164Z     2022-09-20   2022-11-28             False
# ...                        ...            ...          ...               ...
# 3489  2021-06-14T09:32:34.352Z            NaN          NaN              True
# 32    2020-08-20T07:40:24.363Z            NaN          NaN              True
# 1117  2021-10-30T11:53:09.432Z            NaN          NaN              True
# 3490  2020-12-07T11:50:01.855Z            NaN          NaN              True
# 2558  2021-11-17T09:47:07.712Z            NaN          NaN              True
#
#                                      openai_explanation
# 1228  This petition does not relate to the environment.
# 423   This petition does not relate to the environment.
# 3479  This petition relates to air pollution and wil...
# 2516  This petition does not relate to the environment.
# 424   This petition does not relate to the environment.
# ...                                                 ...
# 3489                         Related to the environment
# 32                           Related to the environment
# 1117     related to water pollution and consumer rights
# 3490      related to carbon emissions and cleaner fuels
# 2558          related to palm oil use and air pollution
#
# [273 rows x 12 columns]
